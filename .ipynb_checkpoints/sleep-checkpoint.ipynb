# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sleep.csv', skiprows = 1)
pd.set_option('display.max_columns', None)

# %%
df.index = range(len(df))

# %%
df
# Out:
#    original_efficiency  mental_recovery  factor_01  factor_02  factor_03  \
# 0                 64.0               25         25         13         11
# 1                 61.0                0          0          4          4
# 2                 46.0               33         50          6         19
# 3                 56.0               16         16         14         19
# 4                 87.0               12         13         38          3
#
#    factor_04  factor_05  factor_06  factor_07  factor_08  factor_09  \
# 0         38        437        179          1         14          0
# 1          8         92         76          1          7          0
# 2         61        526        112          3         32          0
# 3         41        500        144          2         24          0
# 4         54        554        147          0         32          0
#
#    factor_10  has_sleep_data  combined_id  data_version  physical_recovery  \
# ...
