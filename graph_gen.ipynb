# %%
import matplotlib.pyplot as plt

# %%
x = [10,100,500,1000, 2000, 5000]
y = [0.116, 0.6132, 8.0521, 20.5254, 68.8928, 364.033]

# %%
plt.plot(x,y, marker = 'o')
plt.xlabel('vector size')
plt.ylabel('process time (ms)')
# Out:
# Text(0, 0.5, 'process time (ms)')
