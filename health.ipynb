# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sleep.csv', skiprows = 1,index_col = False)
pd.set_option('display.max_columns', None)

# %%
df.index = range(len(df))

# %%
df['time_awake'] = df.sleep_duration- (df.efficiency / 100 * df.sleep_duration)

# %%
df.sleep_duration.plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#    original_efficiency  mental_recovery  factor_01  factor_02  factor_03  \
# 0                  NaN             64.0         25         25         13
# 1                  NaN             46.0         33         50          6
# 2                  NaN             87.0         12         13         38
# 3                  NaN             56.0         16         16         14
#
#    factor_04  factor_05  factor_06  factor_07  factor_08  factor_09  \
# 0         11         38        437        179          1         14
# 1         19         61        526        112          3         32
# 2          3         54        554        147          0         32
# 3         19         41        500        144          2         24
#
#    factor_10  has_sleep_data  combined_id  data_version  physical_recovery  \
# 0          0               0          NaN             1               55.0
# 1          0               0          NaN             1               74.0
# ...

# %%
df_s = pd.read_csv('sleep_stage.csv', skiprows = 1,index_col = False)

# %%
df_s = df_s.sort_values(by='start_time')

# %%
df_s
# Out:
#                   start_time                              sleep_id  custom  \
# 0    2021-11-16 01:48:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 4    2021-11-16 02:06:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 59   2021-11-16 02:08:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 101  2021-11-16 02:09:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 132  2021-11-16 02:12:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 182  2021-11-16 02:30:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 1    2021-11-16 02:43:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 8    2021-11-16 02:52:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 60   2021-11-16 02:55:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 103  2021-11-16 02:57:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# 134  2021-11-16 02:58:00.000  89b16e74-6eb2-4167-94ca-31dfff17e4fb     NaN
# ...

# %%
df_s[df_s.sleep_id == '5330feb7-faf0-42e7-8b62-529662f528ae'].plot.scatter('start_time', 'stage')
# Out:
# <AxesSubplot:xlabel='start_time', ylabel='stage'>
